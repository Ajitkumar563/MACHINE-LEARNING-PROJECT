# %%
import seaborn as sns
import pandas as pd
import matplotlib.pyplot as plt

# %%
d=pd.read_csv("customer segmentaion.csv")
d.head()
# Out:
#        ID  Gender Ever_Married  Age Graduated  Profession  Work_Experience  \
# 0  458989  Female          Yes   36       Yes    Engineer              0.0
# 1  458994    Male          Yes   37       Yes  Healthcare              8.0
# 2  458996  Female          Yes   69        No         NaN              0.0
# 3  459000    Male          Yes   59        No   Executive             11.0
# 4  459001  Female           No   19        No   Marketing              NaN
#
#   Spending_Score  Family_Size  Var_1 Segmentation
# 0            Low          1.0  Cat_6            B
# 1        Average          4.0  Cat_6            A
# 2            Low          1.0  Cat_6            A
# 3           High          2.0  Cat_6            B
# 4            Low          4.0  Cat_6            A

# %%
d.columns
# Out:
# Index(['ID', 'Gender', 'Ever_Married', 'Age', 'Graduated', 'Profession',
#        'Work_Experience', 'Spending_Score', 'Family_Size', 'Var_1',
#        'Segmentation'],
#       dtype='object')

# %%
d.dropna()
# Out:
#           ID  Gender Ever_Married  Age Graduated     Profession  \
# 0     458989  Female          Yes   36       Yes       Engineer
# 1     458994    Male          Yes   37       Yes     Healthcare
# 3     459000    Male          Yes   59        No      Executive
# 5     459003    Male          Yes   47       Yes         Doctor
# 6     459005    Male          Yes   61       Yes         Doctor
# ...      ...     ...          ...  ...       ...            ...
# 2621  467950  Female           No   35       Yes  Entertainment
# 2622  467954    Male           No   29        No     Healthcare
# 2623  467958  Female           No   35       Yes         Doctor
# 2625  467961    Male          Yes   47       Yes      Executive
# 2626  467968  Female           No   43       Yes     Healthcare
#
#       Work_Experience Spending_Score  Family_Size  Var_1 Segmentation
# 0                 0.0            Low          1.0  Cat_6            B
# ...

# %%
d=d.dropna()

# %%
d
# Out:
#           ID  Gender Ever_Married  Age Graduated     Profession  \
# 0     458989  Female          Yes   36       Yes       Engineer
# 1     458994    Male          Yes   37       Yes     Healthcare
# 3     459000    Male          Yes   59        No      Executive
# 5     459003    Male          Yes   47       Yes         Doctor
# 6     459005    Male          Yes   61       Yes         Doctor
# ...      ...     ...          ...  ...       ...            ...
# 2621  467950  Female           No   35       Yes  Entertainment
# 2622  467954    Male           No   29        No     Healthcare
# 2623  467958  Female           No   35       Yes         Doctor
# 2625  467961    Male          Yes   47       Yes      Executive
# 2626  467968  Female           No   43       Yes     Healthcare
#
#       Work_Experience Spending_Score  Family_Size  Var_1 Segmentation
# 0                 0.0            Low          1.0  Cat_6            B
# ...

# %%
d.Gender.value_counts()
# Out:
# Male      1184
# Female     970
# Name: Gender, dtype: int64

# %%
sns.countplot(d.Gender)
# Out:
# C:\Users\91892\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='Gender', ylabel='count'>

# %%
plt.scatter(d.index, d.Age)

# %%
plt.scatter(d.index,d.Family_Size)

# %%
sns.scatterplot(d.index,d.Age, hue='Gender', style='Gender', data = d)
# Out:
# C:\Users\91892\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:ylabel='Age'>

# %%
sns.scatterplot(d.index,d.Family_Size, hue='Gender',style='Gender', data = d)
# Out:
# C:\Users\91892\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:ylabel='Family_Size'>

# %%
sns.scatterplot(d.index,d.Age,hue='Family_Size', data = d)
# Out:
# C:\Users\91892\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:ylabel='Age'>

# %%
sns.boxplot(x="Gender", y="Age", data=d )
plt.show()

# %%
sns.boxplot(x="Gender", y="Family_Size", data=d )
plt.show()

# %%
from sklearn import preprocessing
encoder = preprocessing.LabelEncoder()
for i in d.columns:
    if isinstance(d[i][0], str):
            d[i] = encoder.fit_transform(d[i])

# %%
d.Gender.value_counts()
# Out:
# 1    1184
# 0     970
# Name: Gender, dtype: int64

# %%
x = d.drop(['ID'], axis = 1)

# %%
x.head()
# Out:
#    Gender  Ever_Married  Age  Graduated  Profession  Work_Experience  \
# 0       0             1   36          1           2              0.0
# 1       1             1   37          1           5              8.0
# 3       1             1   59          0           4             11.0
# 5       1             1   47          1           1              0.0
# 6       1             1   61          1           1              5.0
#
#    Spending_Score  Family_Size  Var_1  Segmentation
# 0               2          1.0      5             1
# 1               0          4.0      5             0
# 3               1          2.0      5             1
# 5               1          5.0      3             2
# 6               2          3.0      5             3

# %%
y=d['ID']

# %%
y
# Out:
# 0       458989
# 1       458994
# 3       459000
# 5       459003
# 6       459005
#          ...
# 2621    467950
# 2622    467954
# 2623    467958
# 2625    467961
# 2626    467968
# Name: ID, Length: 2154, dtype: int64

# %%
from sklearn.model_selection import train_test_split
train_x, test_x,train_y, test_y = train_test_split(x,y,test_size=.2, random_state = 2)

# %%
from sklearn.neighbors import KNeighborsClassifier

# %%
knn = KNeighborsClassifier()

# %%
knn.fit(train_x,train_y)
# Out:
# KNeighborsClassifier()

# %%
test_x
# Out:
#       Gender  Ever_Married  Age  Graduated  Profession  Work_Experience  \
# 639        0             1   38          1           0              1.0
# 1821       0             1   83          1           7              1.0
# 920        1             0   22          0           5              0.0
# 1459       1             0   42          1           0              8.0
# 1132       1             1   45          1           0              0.0
# ...      ...           ...  ...        ...         ...              ...
# 890        1             1   40          0           2              1.0
# 2164       0             1   52          0           6              4.0
# 200        1             0   25          0           5              0.0
# 564        1             1   77          1           7              1.0
# 947        0             1   41          1           2              8.0
#
#       Spending_Score  Family_Size  Var_1  Segmentation
# ...

# %%
pred = knn.predict(test_x)
print('My predicted values',pred)
print('My actual values', test_y)
# Out:
# My predicted values [460108 459162 459375 459815 459039 461432 460265 460626 463292 459986
#  460976 459026 461370 460214 459213 459617 459658 459041 459853 459571
#  461265 461154 460283 461530 460716 460409 465294 461454 459247 459747
#  460214 464048 459725 459015 462044 461402 460877 462168 459780 459607
#  461476 459170 462202 461432 459467 459077 458994 460897 460822 459459
#  461218 461127 461340 459515 460409 459583 460405 460891 459181 461822
#  461426 460813 459970 459953 460227 459968 461503 459074 461308 460387
#  459760 459591 459175 461187 459658 460861 461873 463423 463173 463509
#  460090 461432 459193 460118 461695 460212 462428 461558 462529 459041
#  459117 459795 459213 460243 459375 459117 461016 459353 459587 459284
#  459117 460167 460763 461556 459208 459428 460122 460265 460196 460206
#  461402 459320 461121 460769 461457 459247 459003 459897 460638 463654
#  459541 459725 460924 459024 460877 461024 459673 460687 463664 463443
# ...

# %%
from sklearn.metrics import accuracy_score
accuracy_score(pred,test_y)
# Out:
# 0.0
